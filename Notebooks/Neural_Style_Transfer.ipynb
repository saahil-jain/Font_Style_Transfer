# %%
# %%time
import os
% cd /content/
if os.path.isdir("Font_Style_Transfer"):
  print("Font_Style_Transfer already Exists")
else:
  ! git clone https://github.com/saahil-jain/Font_Style_Transfer.git
% cd Font_Style_Transfer
! git pull
% cd Code

# %%
% cd /content/Font_Style_Transfer/Code/

letter="013.png"
Style="Locomo" 
style_letter="042.png"
epochs=4000
image_size=200
learning_rate=0.01
alpha=10
beta=0.8
# !python3 nst.py $letter $Style $style_letter $epochs $image_size $learning_rate $alpha $beta

# %%
% cd /content/Font_Style_Transfer/Code/

import os 
import time


base = "Kannada_Fonts/Belur"
letters = os.listdir(base)
letters.sort()
letters = letters[10:15]

Style="Locomo" 
style_letter="042.png"
epochs=4000
image_size=200
learning_rate=0.01
alpha=10
beta=0.8

for letter in letters:
    target_directory = "Generated/"+Style
    if not os.path.isdir(target_directory):
      # !mkdir $target_directory
    # !python3 nst.py $letter $Style $style_letter $epochs $image_size $learning_rate $alpha $beta
