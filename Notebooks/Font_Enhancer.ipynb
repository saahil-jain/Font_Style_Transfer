# %%
# %%time
import os
% cd /content/
if os.path.isdir("Font_Style_Transfer"):
  print("Font_Style_Transfer already Exists")
else:
  ! git clone https://github.com/saahil-jain/Font_Style_Transfer.git
% cd Font_Style_Transfer
! git pull
% cd /content/Font_Style_Transfer/Code/Generated

# %%
% cd /content/Font_Style_Transfer/Code/Generated
% cd Locomo

from google.colab.patches import cv2_imshow
from PIL import Image, ImageFilter
from imutils import contours
from skimage import measure
import numpy as np
import cv2

generated_image = "016_O.png"
image = cv2.imread(generated_image)
# cv2_imshow(image)

image = cv2.addWeighted(image, 2, np.zeros(image.shape, image.dtype), 0, -100)
image = cv2.cvtColor(image ,cv2.COLOR_RGB2GRAY)
_,image = cv2.threshold(image,150,255,cv2.THRESH_BINARY)
cv2_imshow(image)

# image = cv2.cvtColor(image ,cv2.COLOR_RGB2GRAY)
# kernel = np.ones((5,5),np.uint8)
# image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
# image = cv2.equalizeHist(image)
# image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
# cv2_imshow(image)
# cv2.waitKey(5000)


# image = cv2.medianBlur(image, 3)
# cv2_imshow(image)
# image = cv2.erode(image, None, iterations=1)
# cv2_imshow(image)


# image = cv2.Canny(image,100,200)
# cv2_imshow(image)
# image = (255 - image)
# cv2_imshow(image)


# kernel = np.ones((5,5),np.uint8)
# _,image = cv2.threshold(image,1,255,cv2.THRESH_TRUNC)

# image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
# image = cv2.equalizeHist(image)
# cv2_imshow(image)
# image = cv2.medianBlur(image, 5)
# cv2_imshow(image)
# image = cv2.GaussianBlur(image,(5,5),0)
# image = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
# image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
# cv2_imshow(image)


# _,image = cv2.threshold(image,245,255,cv2.THRESH_BINARY)
# cv2_imshow(image)
# image = cv2.medianBlur(image, 3)
# cv2_imshow(image)
# n_white_pix = np.sum(image == 255)
# print(n_white_pix)

# im = image
# ret, thresh = cv2.threshold(im, 240, 255, 0)
# contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# image = cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)
# cv2.drawContours(image, contours, -1, (240,255,0), 3)
# cv2_imshow(image)
# im = cv2.cvtColor(image ,cv2.COLOR_RGB2GRAY)
# image = cv2.addWeighted(image, 2, np.zeros(image.shape, image.dtype), 0, -256)
# cv2_imshow(image)



# image = Image.fromarray(image.astype('uint8'))
# image = image.filter(ImageFilter.UnsharpMask(radius=7, percent=50))
# image = np.array(image)
# cv2_imshow(image)
# image = cv2.medianBlur(image, 11)
# cv2_imshow(image)

# %%
% cd /content/Font_Style_Transfer/Code/Generated
% cd Locomo

from google.colab.patches import cv2_imshow
from PIL import Image, ImageFilter
from imutils import contours
from skimage import measure
import numpy as np
import cv2

image_names = os.listdir()
image_names.sort()
generated_images = []
for image_name in image_names:
  if "_O" in image_name:
    generated_images.append(image_name)
generated_images

for generated_image in generated_images:
  image = cv2.imread(generated_image)
  # cv2_imshow(image)
  # image = cv2.addWeighted(image, 2, np.zeros(image.shape, image.dtype), 0, -100)
  # cv2_imshow(image)
  image = cv2.cvtColor(image ,cv2.COLOR_RGB2GRAY)
  _,image = cv2.threshold(image,200,255,cv2.THRESH_BINARY)
  cv2_imshow(image)
  cv2.imwrite(generated_image, image)
